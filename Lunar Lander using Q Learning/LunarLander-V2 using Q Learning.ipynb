# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
# %matplotlib inline

# %%
from collections import defaultdict
import random, math
import numpy as np

class QLearningAgent:
    def __init__(self, alpha, epsilon, discount, get_legal_actions):

        self.get_legal_actions = get_legal_actions
        self._qvalues = defaultdict(lambda: defaultdict(lambda: 0))
        self.alpha = alpha
        self.epsilon = epsilon
        self.discount = discount

    def get_qvalue(self, state, action):

        return self._qvalues[state][action]

    def set_qvalue(self,state,action,value):

        self._qvalues[state][action] = value

    def get_value(self, state):

        possible_actions = self.get_legal_actions(state)

        #If there are no legal actions, return 0.0
        if len(possible_actions) == 0:
            return 0.0

        value_space = []
        for action in possible_actions:
            value_space.append(self.get_qvalue(state, action))
        value = np.max(value_space)
        return value

    def update(self, state, action, reward, next_state):

        #agent parameters
        gamma = self.discount
        learning_rate = self.alpha

        new_q = (1-learning_rate) * self.get_qvalue(state, action)
        new_q += learning_rate * (reward + gamma * self.get_value(next_state))
        
        self.set_qvalue(state, action, new_q)

    
    def get_best_action(self, state):
 
        possible_actions = self.get_legal_actions(state)

        #If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        action_space = []
        for action in possible_actions:
            action_space.append(self.get_qvalue(state,action))
        best_action = possible_actions[np.argmax(action_space)]

        return best_action

    def get_action(self, state):

        # Pick Action
        possible_actions = self.get_legal_actions(state)
        action = None

        #If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        #agent parameters:
        epsilon = self.epsilon

        choice = np.random.choice(2, p = [epsilon,1-epsilon])
        if choice == 1: chosen_action = self.get_best_action(state)
        else: chosen_action = np.random.choice(possible_actions)
        
        return chosen_action

# %%
from gym.core import ObservationWrapper
class Binarizer(ObservationWrapper):
    
    def _observation(self, state):    
        
        #state = <round state to some amount digits.>
        #hint: you can do that with round(x,n_digits)
        #you will need to pick a different n_digits for each dimension
        n_digits = [2,2,2,2,2,2,0,0]
        for i in range(len(n_digits)):
            state[i] = np.round(state[i],n_digits[i])
        
        return tuple(state)

# %%
import gym
env = Binarizer(gym.make("LunarLander-v2"))
n_actions = env.action_space.n
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
print("n_actions:", env.action_space.n)
# Out:
# Observation space: Box(8,)
# Action space: Discrete(4)
# n_actions: 4
# /home/otoshuki/anaconda/envs/tensorflow/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
all_states = []
for _ in range(1000):
    all_states.append(env.reset())
    done = False
    while not done:
        s, r, done, _ = env.step(env.action_space.sample())
        all_states.append(s)
        if done: break
            
all_states = np.array(all_states)

for obs_i in range(env.observation_space.shape[0]):
    print(obs_i)
    plt.hist(all_states[:,obs_i],bins=100)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
total_reward = 0
def play_and_train(env,agent,t_max=10**4):

    total_reward = 0.0
    s = env.reset()
    
    for t in range(t_max):
        # get agent to pick action given state s.
        a = agent.get_action(s)
        
        next_s, r, done, _ = env.step(a)
        
        # train (update) agent for state s
        agent.update(s,a,r,next_s)
        env.render()
        s = next_s
        total_reward +=r
        if done: break
        
    return total_reward

# %%
agent = QLearningAgent(alpha=0.4, epsilon=0.1, discount=0.99,
                       get_legal_actions = lambda s: range(n_actions))

# %%
#Training
from IPython.display import clear_output

rewards = []
env.reset()
for i in range(10000):
    rewards.append(play_and_train(env,agent))   
      
    if i %100 ==0:
        agent.epsilon *= 0.95
        clear_output(True)
        print('eps =', agent.epsilon, 'mean reward =', np.mean(rewards[-10:]))
        plt.plot(rewards)
        plt.show()
        if np.mean(rewards[-10:]) > 50:
            print("Done")
            break
print(len(agent._qvalues))
# Out:
# eps = 0.04401266686517654 mean reward = -95.09752455886444
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-c53444aa0763> in <module>()
#       5 env.reset()
#       6 for i in range(10000):
# ----> 7     rewards.append(play_and_train(env,agent))
#       8
#       9     if i %100 ==0:
#
# <ipython-input-75-1a8aeea34d6a> in play_and_train(env, agent, t_max)
#       9     for t in range(t_max):
#      10         # get agent to pick action given state s.
# ---> 11         a = agent.get_action(s)
#      12
#      13         next_s, r, done, _ = env.step(a)
#
# <ipython-input-72-a5b5a44207df> in get_action(self, state)
#      74         epsilon = self.epsilon
#      75
# ---> 76         choice = np.random.choice(2, p = [epsilon,1-epsilon])
#      77         if choice == 1: chosen_action = self.get_best_action(state)
#      78         else: chosen_action = np.random.choice(possible_actions)
#
# KeyboardInterrupt:

# %%
#Display final results
fig = plt.figure()
ax = fig.add_subplot(111)
total_reward = 0
s = env.reset()
#env.render()
for t in range(10000):
    #Action probabilities in current state
    a = agent.get_action(s)
    new_s, r, done, info = env.step(a)
    total_reward += r
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    agent.update(s,a,r,new_s)
    #Set the new state
    s = new_s
    if done: break
print(total_reward)
# Out:
# -118.90155689150394
