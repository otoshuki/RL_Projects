# %%
import os
import time
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as L
from IPython.display import clear_output
#ENV Stuff
from rocket import Rocket
import utils

# %matplotlib inline
# Out:
# 2024-06-07 16:54:22.746596: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 16:54:22.746620: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 16:54:22.747494: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-07 16:54:22.752100: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-07 16:54:23.344885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-06-07 16:54:23.999394: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-07 16:54:24.022466: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-07 16:54:24.022599: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Environment Setup
#
# #### We are using Zhengxia Zou, Rocket-recycling with Reinforcement Learning, 2021
#
# #### Repo Link: https://github.com/jiupinjia/rocket-recycling
#
# We will be focusing on the landing problem with rockets

# %%
task = 'hover'
num_steps = 800 #Environment steps
env = Rocket(task=task, max_steps=num_steps)
obs_N = env.state_dims #Observations are position, speed, angle, angle velocity, nozzle angle, and the simulation time
act_N = env.action_dims #Actions are 3 thrust values in 3 directions

# %% [markdown]
# ## Agent Setup
#
# #### We wrote our own PPO-CLIP agent in Tensorflow 2
# Actor            |  Critic
# :-------------------------:|:-------------------------:
# <img src="actor.png" alt="actor" width="200"/>  |  <img src="critic.png" alt="critic" width="200"/>
#
# ### Overall algorithm
# * Initialize actor(policy), critic networks
# * Collect trajectory(t=0 to T) in TRAJ
#     * a = sample($\pi_{\theta_k}(a|s)$)
#     * s', r, d = env.step(a)
#     * logprob = $log(\pi_{\theta_k}(a|s)))$
# * Calculate Advantage A using Generalized Advantage Estimation
# * Calculate Reward-to-go RTG
# * Update Actor
#     * Get $log(\pi_\theta(a|s))$ using TRAJ
#     * Calculate Diff: $log(\pi_\theta(a|s))-log(\pi_{\theta_k}(a|s))$
#     * Calculate Ratio: exp(diff)
#     * Calculate Loss: $\mathbb{E}_t$[min(Ratio\*A, clip(Ratio, 1-$\epsilon$, 1+$\epsilon$)\*A)]
#     * Perform gradient descent on -Loss
# * Update Critic
#     * Get $V(s)$ using critic
#     * Calculate Diff: $V(s)-RTG$
#     * Calculate Loss: MSE(Diff)
#     * Perform gradient descent on Loss

# %%
def createActor(obs_N, act_N):
    """
    Create Actor Model: Pi(a|s)
    inp->fc1->relu->fc2->relu->fc3->softmax out
    """
    inp = keras.Input(shape=obs_N, name='obs_input')
    x = L.Dense(64, kernel_initializer='he_uniform', activation='relu', name='fc1')(inp)
    x = L.Dense(32, kernel_initializer='he_uniform', activation='relu', name='fc2')(x)
    out = L.Dense(act_N, kernel_initializer='he_uniform', activation='softmax', name='fc3')(x)
    model = keras.Model(inputs=inp, outputs=out, name='actor')
    return model

def createCritic(obs_N):
    """
    Create Critic Model: V(s)
    inp->fc1->relu->fc2->relu->fc3->linear out
    """
    inp = keras.Input(shape=obs_N, name='obs_input')
    x = L.Dense(64, kernel_initializer='he_uniform', activation='relu', name='fc1')(inp)
    x = L.Dense(32, kernel_initializer='he_uniform', activation='relu', name='fc2')(x)
    out = L.Dense(1, kernel_initializer='he_uniform', name='fc3')(x)
    model = keras.Model(inputs=inp, outputs=out, name='critic')
    return model

class PPOClipAgent:
    def __init__(self, obs_N, act_N, actor_lr=1e-3, critic_lr=1e-3, gamma=0.9, clip=0.2, lmbda=0.95, summary=None):
        #Agent parameters
        self.obs_N = obs_N
        self.act_N = act_N
        self.actor_lr = actor_lr
        self.critic_lr = critic_lr
        self.gamma = gamma
        #Networks
        self.actor = createActor(obs_N, act_N)
        self.critic = createCritic(obs_N)
        #Optimizers
        self.actor_optimizer = keras.optimizers.Adam(learning_rate=actor_lr)
        self.critic_optimizer = keras.optimizers.Adam(learning_rate=critic_lr)
        #PPO specifics
        self.clip = clip
        self.lmbda = lmbda

    def get_action(self, obs):
        """
        Return a discrete action from actor's softmax distribution
        """
        action_probs = self.actor(np.atleast_2d(obs))
        action = np.random.choice(np.arange(self.act_N), p=action_probs.numpy().flatten())
        return action, action_probs

    def get_gae_and_rtg(self, s, r, next_s, done):
        """
        Use generalized advantage estimation of the current batch of samples
        Also calculate the rewards to go, which is nothing but sum of discounted rewards from current state
        """
        #Current critic estimate of V(s)
        v_vals_s = self.critic(np.atleast_2d(s)).numpy()
        #Current critic estimate of V(s')
        #Please note this is essentially shifted i.e. s'(t)=s(t+1), but using it here to make implementation easy
        v_vals_next_s = self.critic(np.atleast_2d(next_s)).numpy()
        #Buffer
        advantage = np.zeros(len(r)+1)
        rewards_to_go = np.zeros(len(r)+1)
        #td_T calculation
        td_err = r[-1] + self.gamma*v_vals_next_s[-1]*(1-done) - v_vals_s[-1]
        #r_T calculation
        rewards_to_go[-1] = r[-1]
        for i in reversed(range(len(r))):
            #A_t = td_t + gamma*lambda*A_t+1
            advantage[i] = td_err + self.gamma*self.lmbda*advantage[i+1]
            #td_t-1 calculation
            td_err = r[i] + self.gamma*v_vals_next_s[i] - v_vals_s[i]
            #Rewards to go
            rewards_to_go[i] = r[i] +  self.gamma*(rewards_to_go[i+1])
        #Final entries are 0 for adv and rtg, we don't need them
        advantage = advantage[:-1]
        rewards_to_go = rewards_to_go[:-1]
        #Normalize advantage
        advatange = (advantage-advantage.mean())/(advantage.std() + 1e-10)
        return advantage, rewards_to_go

    def train_step(self, s, a, r, next_s, done, logprobs):
        """
        Train using experiences
        """
        #Get advantage and rtg values
        adv, rtg = self.get_gae_and_rtg(s, r, next_s, done)
        #Actor Update
        actor_learnables = self.actor.trainable_variables
        with tf.GradientTape() as tape:
            curr_logprobs = tf.math.log(self.actor(s))
            diff_logprobs = curr_logprobs-tf.squeeze(logprobs)
            ratio = tf.reduce_sum(tf.math.exp(diff_logprobs)*tf.one_hot(a, self.act_N), axis=1)
            surrogate1 = ratio*adv
            surrogate2 = tf.clip_by_value(ratio, 1-self.clip, 1+self.clip)*adv
            actor_loss = -tf.math.reduce_mean(tf.math.minimum(surrogate1, surrogate2))
            actor_grad = tape.gradient(actor_loss, actor_learnables)
        self.actor_optimizer.apply_gradients(zip(actor_grad, actor_learnables))
        #Critic Update
        critic_learnables = self.critic.trainable_variables
        with tf.GradientTape() as tape:
            #Squeeze was needed to make sure the sizes align
            v_vals_s = tf.squeeze(self.critic(s))
            #Critic loss is mean(r-v)^2
            critic_loss = tf.math.reduce_mean(tf.math.square(rtg - v_vals_s))
            critic_grad = tape.gradient(critic_loss, critic_learnables)
        self.critic_optimizer.apply_gradients(zip(critic_grad, critic_learnables))
        return actor_loss.numpy(), critic_loss.numpy()

# %%
agent = PPOClipAgent(obs_N, act_N, actor_lr=3e-4, critic_lr=1e-3, gamma=0.99, lmbda=0.97)

# %% [markdown]
# ## Training

# %%
num_iters = 10000 #Training iterations
num_epochs = 20 #Number of gradient steps
train_rewards = []
actor_losses = []
critic_losses = []
for it in range(num_iters):
    #Reset env
    s = env.reset()
    #Empty buffers to store episode
    s_buff = []
    a_buff = []
    r_buff = []
    next_s_buff = []
    logprobs_buff = []
    #Reminder that done will not be stored since we train only at the end of episode
    #Run environment
    for t in range(num_steps):
        #Get action
        a, a_prob = agent.get_action(s)
        #Step env forward
        next_s, r, done, info = env.step(a)
        #Extra step for done at end of env steps
        if t == num_steps-1:
            done = True
        #Batch collect samples
        s_buff.append(s)
        a_buff.append(a)
        r_buff.append(r)
        next_s_buff.append(next_s)
        logprobs_buff.append(np.log(a_prob))
        #Set next state
        s = next_s
        #If complete break out of current episode
        if done:
            break
    #Ease of use with np arrays
    s_buff = np.array(s_buff)
    a_buff = np.array(a_buff)
    r_buff = np.array(r_buff)
    next_s_buff = np.array(next_s_buff)
    logprobs_buff = np.array(logprobs_buff)
    #We are training only at the end of episode
    a_loss_mean = 0
    c_loss_mean = 0
    for epoch in range(num_epochs):
        a_loss, c_loss = agent.train_step(s_buff, a_buff, r_buff, next_s_buff, done, logprobs_buff)
        a_loss_mean += a_loss
        c_loss_mean += c_loss
    #Utilities
    cum_rew = np.sum(r_buff)
    train_rewards.append(cum_rew)
    actor_losses.append(a_loss_mean/num_epochs)
    critic_losses.append(c_loss_mean/num_epochs)
    clear_output(True)
    plt.subplot(3, 1, 1)
    plt.title("rewards")
    plt.plot(train_rewards)
    plt.plot(utils.moving_avg(train_rewards, N=10))
    plt.grid()
    plt.subplot(3, 1, 2)
    plt.title("ac loss")
    plt.plot(actor_losses)
    plt.plot(utils.moving_avg(actor_losses, N=10))
    plt.grid()
    plt.subplot(3, 1, 3)
    plt.title("cr loss")
    plt.plot(critic_losses)
    plt.plot(utils.moving_avg(critic_losses, N=10))
    plt.grid()
    plt.show()
    print('Iteration: {}, Reward: {}'.format(it, cum_rew))
# Out:
# Iteration: 1443, Reward: 26.01162142484081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 19
#      15 #Reminder that done will not be stored since we train only at the end of episode
#      16 #Run environment
#      17 for t in range(num_steps):
#      18     #Get action
# ---> 19     a, a_prob = agent.get_action(s)
#      20     #Step env forward
#      21     next_s, r, done, info = env.step(a)
#
# Cell In[14], line 47, in PPOClipAgent.get_action(self, obs)
#      43 def get_action(self, obs):
#      44     """
#      45     Return a discrete action from actor's softmax distribution
#      46     """
# ---> 47     action_probs = self.actor(np.atleast_2d(obs))
#      48     action = np.random.choice(np.arange(self.act_N), p=action_probs.numpy().flatten())
#      49     return action, action_probs
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/engine/training.py:590, in Model.__call__(self, *args, **kwargs)
#     586         super().__call__(inputs, *copied_args, **copied_kwargs)
#     588     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 590 return super().__call__(*args, **kwargs)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/engine/functional.py:515, in Functional.call(self, inputs, training, mask)
#     496 @doc_controls.do_not_doc_inheritable
#     497 def call(self, inputs, training=None, mask=None):
#     498     """Calls the model on new inputs.
#     499
#     500     In this case `call` just reapplies
#    (...)
#     513         a list of tensors if there are more than one outputs.
#     514     """
# --> 515     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/engine/functional.py:672, in Functional._run_internal_graph(self, inputs, training, mask)
#     669     continue  # Node is not computable, try skipping.
#     671 args, kwargs = node.map_arguments(tensor_dict)
# --> 672 outputs = node.layer(*args, **kwargs)
#     674 # Update tensor_dict.
#     675 for x_id, y in zip(
#     676     node.flat_output_ids, tf.nest.flatten(outputs)
#     677 ):
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1075, in Layer.__call__(self, *args, **kwargs)
#    1070 # Accept NumPy and scalar inputs by converting to Tensors.
#    1071 if any(
#    1072     isinstance(x, (tf.Tensor, np.ndarray, float, int))
#    1073     for x in input_list
#    1074 ):
# -> 1075     inputs = tf.nest.map_structure(
#    1076         _convert_numpy_or_python_types, inputs
#    1077     )
#    1078     input_list = tf.nest.flatten(inputs)
#    1080 # Handle `mask` propagation from previous layer to current layer. Masks
#    1081 # can be propagated explicitly via the `mask` argument, or implicitly
#    1082 # via setting the `_keras_mask` attribute on the inputs to a Layer.
#    1083 # Masks passed explicitly take priority.
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/tensorflow/python/util/nest.py:631, in map_structure(func, *structure, **kwargs)
#     545 @tf_export("nest.map_structure")
#     546 def map_structure(func, *structure, **kwargs):
#     547   """Creates a new structure by applying `func` to each atom in `structure`.
#     548
#     549   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1066, in map_structure(modality, func, *structure, **kwargs)
#     969 """Creates a new structure by applying `func` to each atom in `structure`.
#     970
#     971 - For Modality.CORE: Refer to
#    (...)
#    1063   ValueError: If wrong keyword arguments are provided.
#    1064 """
#    1065 if modality == Modality.CORE:
# -> 1066   return _tf_core_map_structure(func, *structure, **kwargs)
#    1067 elif modality == Modality.DATA:
#    1068   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1102, in _tf_core_map_structure(func, *structure, **kwargs)
#    1094   _tf_core_assert_same_structure(
#    1095       structure[0],
#    1096       other,
#    1097       check_types=check_types,
#    1098       expand_composites=expand_composites,
#    1099   )
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
# -> 1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
#    1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# File ~/anaconda3/envs/daily/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1101, in <genexpr>(.0)
#    1093 for other in structure[1:]:
#    1094   _tf_core_assert_same_structure(
#    1095       structure[0],
#    1096       other,
#    1097       check_types=check_types,
#    1098       expand_composites=expand_composites,
#    1099   )
# -> 1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
#    1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
s = env.reset()
cum_reward = 0
for t in range(num_steps):
    a, _ = agent.get_action(s)
    next_s, r, done, _= env.step(a)
    frame_0, frame_1 = env.render()
    cv2.imshow('fr', frame_0[:,:,::-1])
    cv2.waitKey(1)
    cv2.imshow('fr', frame_1[:,:,::-1])
    cv2.waitKey(1)
    if done:
        break
    if env.already_crash:
        break
# Out:
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
#
# QObject::moveToThread: Current thread (0x80532a0) is not the object's thread (0x1836d860).
# Cannot move to target thread (0x80532a0)
