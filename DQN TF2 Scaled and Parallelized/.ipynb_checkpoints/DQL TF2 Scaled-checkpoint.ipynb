# %% [markdown]
# # Approximate (Deep) Q-Learning
# ## Using TF-2
# ## Using Experience replay
# ## Using Target Network
# ## Parallelized Sessions
#
# ### First tested on CartPole-V0
# ### Now on LunarLander-V2-Discrete
#
# ##### This is another oop approach

# %%
import gym
from joblib import Parallel, delayed
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## TF Stuff to do beforehand

# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as L

# %%
#Checking GPU Use
if tf.test.gpu_device_name(): 

    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device:/device:GPU:0

# %% [markdown]
# ## Create our DNN model to be used for approximating Q values
#
# #### Currently this is just a simple model
# `Input(state_dims) -> Dense(400, relu) -> Dense(400, relu) -> Dense(n_actions, linear)`
#
# ##### Subclassing allows for more complex networks, so yeah this is good
#
# ![our%20model.jpg](attachment:our%20model.jpg)
#
# If you know you know

# %%
#We need to first create our custom model class
#This can be utilized for more complex networks

class OurDNN(keras.Model):
    def __init__(self, input_dim, output_dim):
        super(OurDNN, self).__init__()
        #Input layer
        self.inp = L.InputLayer(input_dim)
        #Hidden layers here - ReLu
        self.hd1 = L.Dense(128, kernel_initializer='uniform', activation='relu')
        self.hd2 = L.Dense(64, kernel_initializer='uniform', activation='relu')
        #Output layer here - linear
        self.out = L.Dense(output_dim, kernel_initializer='uniform', activation='linear')
    
    @tf.function
    def call(self, input_data):
        #Essentially feedforward your network
        inp_fwd = self.inp(input_data)
        hd1_fwd = self.hd1(inp_fwd)
        hd2_fwd = self.hd2(hd1_fwd)
        out_fwd = self.out(hd2_fwd)
        #Get the output
        return out_fwd

# %% [markdown]
# ## Create our AQL Agent
#
# ### The loss function for our agent is defined as -
# $$ L(w) = { 1 \over N} \sum_i (Q_{\theta}(s,a,w) - [r(s,a) + \gamma \cdot max_{a'} Q_{-}(s', a')]) ^2 $$
#
# Where
# * $s, a, r, s'$ are current state, action, reward and next state respectively
# * $\gamma$ is a discount factor defined two cells above.
#
# ### The update equation is defined as
# $$ \textbf{w} \leftarrow \textbf{w} + \alpha*\nabla_{\textbf w}L(\textbf w)$$
#
# ### Here we have two identical neural networks!
# #### 1. Q-network which will be used to calculate $Q_{\theta}(s_t,a_t)$
# #### 2. Target network which will be used to calculate  $Q_{-}(s_{t+1},a)$
#
# This target network is updated at very target_steps time steps using the params of the Q-network - Hard Copy method
#
# Solves the problem of error propagation in TD learning

# %%
class OurAgent:
    def __init__(self, envs, alpha=0.01, epsilon=0.5, gamma=0.99, buffer_size=512, load=False):
        
        #Set up constants
        self.state_dim = envs[0].observation_space.shape
        self.n_actions = envs[0].action_space.n
        self.gamma = gamma
        self.epsilon = epsilon
        self.envs = envs
        self.optimizer = tf.keras.optimizers.Adam(alpha)
        self.target_model = None
        
        self.num_envs = len(envs)
        
        #Create the model - Q-network
        if load:
            self.model = keras.models.load_model("./models/tf2_lunar_model/")
            self.model.summary()
        else:
            self.model = OurDNN(self.state_dim, self.n_actions)
            self.model.compile(self.optimizer)
        
        #Set up experience replay
        self.buffer = ReplayBuffer(buffer_size)
        print("LOG: Using Experience Replay")
        
        #Set up target network
        #If loaded q-network, then directly load
        if load:
            #Doing this since I had trouble with copying weights
            #from a pretrained model
            self.target_model = keras.models.load_model("./models/tf2_lunar_model/")
        #In case it is new
        else:
            self.target_model = OurDNN(self.state_dim, self.n_actions)
            self.target_model.compile(self.optimizer)
            self.q_to_target()
        print("LOG: Using Target Network")
        
    def get_actions(self, states):
        '''
        Uses E-greedy policy to get the agent actions
        '''
        #Approximate the q_values
        q_values = self.model.predict(states)
        
        #Explore or exploit
        ore_or_oit = np.random.choice([0,1], p =[self.epsilon, 1-self.epsilon])
        #If wanna explore
        if ore_or_oit == 0:
            chosen_actions = np.random.choice(self.n_actions, self.num_envs) #Over uniform dist
        #If wanna exploit
        else:
            chosen_actions = np.argmax(q_values, axis=1)
            
        return chosen_actions
 
    def q_to_target(self):
        '''
        Copy Q-network weights to Target-network
        '''
        self.target_model.set_weights(self.model.get_weights())

    def get_loss(self, state, action, next_state, reward, is_done):
        '''
        Get the loss function as defined above
        '''
        #Get 𝑄𝜃(s,a) using Q-network
        pred_q = self.model(np.atleast_2d(state.astype('float32')))
        pred_q_for_a = tf.reduce_sum(pred_q * tf.one_hot(action, self.n_actions), axis=1)
         
        #Get Q_(s',a') using Target-network
        pred_next_q = self.target_model(np.atleast_2d(next_state.astype('float32')))
        #Get V_(s',a') using Q
        next_v = tf.math.reduce_max(pred_next_q, axis=1)
        #Get target Q-value, Q_(s',a')
        target_q_for_a = reward + self.gamma*next_v
        # at the last state we shall use simplified formula: Q(s,a) = r(s,a) since s' doesn't exist
        target_q_for_a = tf.where(is_done, reward, target_q_for_a)
        
        #Calculate loss
        loss = (pred_q_for_a - target_q_for_a) ** 2
        loss = tf.reduce_mean(loss)
        return loss
        
    def train_q_net(self, batch_size):
        '''
        Trains the given network wrt the custom loss function
        '''
        #Variables to train - here weight
        variables = self.model.trainable_variables
        
        #Sample from buffer
        s,a,r,next_s,done = self.buffer.sample(batch_size)
        
        #Update upon each sample
        for i in range(batch_size):
            #Perform approx Q Learning with Adam optimizer
            with tf.GradientTape() as tape:
                loss = self.get_loss(s[i],a[i], next_s[i], r[i], done[i])
                gradients = tape.gradient(loss, variables)
                self.optimizer.apply_gradients(zip(gradients, variables))
    
    def env_step(self, env_index, action, envs_running):
        '''
        Perform step action for particular environment
        '''
        #Convenience function for joblib
        #Performs env run only if it's running
        if env_index in envs_running:
            return self.envs[env_index].step(action)
        else:
            return np.array([np.zeros(self.state_dim), 0.0, True, {}])
    
    def generate_session(self, t_max=1000, train=False, batch_size=128, target_steps=256):
        '''
        Run environment and train
        '''
        total_reward = np.zeros(self.num_envs)
        self.num_envs = len(self.envs)
        #Run num_envs number of environments in parallel
        s = np.array(Parallel(n_jobs=self.num_envs, prefer="threads")
                     (delayed(self.envs[i].reset)() for i in range(self.num_envs)))
        
        #Create a list of running environment indexes
        envs_started = np.array(range(self.num_envs))
        envs_running = envs_started
        
        num_done = 0
        
        for t in range(t_max):
            #Get the length of current environments
            self.num_run = len(envs_running)
            
            a = self.get_actions(s)
            #Run these sessions in parallel
            out = np.array(Parallel(n_jobs=self.num_envs, prefer="threads")
                           (delayed(self.env_step)(i,a[i],envs_running) for i in range(self.num_envs)))
            
            next_s, r, done, _ = np.rollaxis(out,1)
#             print(next_s)         
            next_s = np.stack(next_s)
            
            #Send data from running environments to the replay buffer
            Parallel(n_jobs=self.num_envs, prefer="threads")(delayed(self.buffer.add)(s[i],a[i],r[i],next_s[i],done[i]) for i in envs_running)

            #If wanna train
            if train:
                #After the first few samples
                if len(self.buffer) > batch_size:
                    self.train_q_net(batch_size)
              
                #If using target_networks and after target_steps time
                if (t+1)%target_steps==0:
                    #Copy weights to target
                    self.q_to_target()
                    
            #Only update rewards for those that are running
            total_reward[done==False] = total_reward[done==False]+r[done==False]
            s = next_s
            #Set the running environments from the ones that started
            envs_running = envs_started[done == False]
            #If all environments are over
            if done.all():
                break
                
        return total_reward
    
    def generate_single_session(self, env, t_max=1000):
        '''
        Run environment and train
        '''
        total_reward = 0
        s = self.env.reset()
        
        for t in range(t_max):
            a = self.get_action(s)
            next_s, r, done, _ = self.env.step(a)
            
            total_reward += r
            s = next_s
            if done:
                break
        
        return total_reward
    
    def save(self):
        self.model.save("./models/tf2_lunar_model", save_format="tf")

# %% [markdown]
# ## Create Experience Replay Buffer using deque

# %%
from collections import deque
#Deque has a better time complexity

class ReplayBuffer(object):
    def __init__(self, size):
        """
        Create Replay buffer.
        """
        self._storage = deque(maxlen=size)

    def __len__(self):
        return len(self._storage)
    
    def add(self, obs_t, action, reward, obs_tp1, done):
        '''
        Add new elements into the FIFO buffer
        '''
        data = (obs_t, action, reward, obs_tp1, done)
        #Now append the data
        self._storage.append(data)
    
    def sample(self, batch_size):
        """
        Sample a batch of experiences.
        """
        #Sample random indexes from the buffer
        idxes = np.random.randint(len(self._storage), size=batch_size)

        #First convert the data to numpy array
        np_storage = np.array(self._storage)
        
        #Now use these indexes to get the samples
        samples = np_storage[idxes]
        #Return corresponding values
        return(
#             np.stack(samples[:,0]),
            samples[:,0],
            samples[:,1],
            samples[:,2],
#             np.stack(samples[:,3]),
            samples[:,3],
            samples[:,4]
        )

# %% [markdown]
# ## Time to run stuff

# %%
#Create 8 environments for 8 cores
# envs = [gym.make("LunarLander-v2").env for i in range(8)]
envs = [gym.make("CartPole-v0").env for i in range(8)]

# %%
#Replay buffer is a necessity here
#Agent using cartpole environments and Adam optimizer
agent = OurAgent(envs, load=True)
# Out:
# LOG: Using Experience Replay
# LOG: Using Target Network

# %%
from IPython.display import clear_output

mean_rewards = []

max_reward = 0

try:
    for i in range(1000):
        session_rewards = agent.generate_session(train=True)
        mean_rewards.append(np.mean(session_rewards))
        #Make sure epsilon doesn't go below 0.1
        if agent.epsilon > 0.1:
            agent.epsilon *= 0.99
        clear_output(True)
        print("epoch #{}\tmean reward = {:.3f}\tepsilon = {:.3f}".format(i, np.mean(session_rewards), agent.epsilon))
        plt.plot(mean_rewards)
        plt.show()
        #Save weights for a new best state
        if mean_rewards[i] > max_reward:
            max_reward = mean_rewards[i]
            agent.save()
        if np.mean(session_rewards) > 300:
            print("You Win! Stop using Keyboard Interrupt")
    #         break
    
except KeyboardInterrupt:
    clear_output(True)
    print("Stopped")
    print("epoch #{}\tmean reward = {:.3f}\tepsilon = {:.3f}".format(i, np.mean(session_rewards), agent.epsilon))
    plt.plot(mean_rewards)
    plt.show()
# Out:
# Stopped
# epoch #36	mean reward = 26.000	epsilon = 0.348

# %%
agent.save()
# Out:
# INFO:tensorflow:Assets written to: ./models/tf2_lunar_model/assets

# %%
# Record sessions
import gym.wrappers

with gym.wrappers.Monitor(gym.make("CartPole-v0"), directory="videos", force=True) as env_monitor:
    agent.envs = [env_monitor]
    
    sessions = [agent.generate_single_session(train=False) for _ in range(10)]
    print(sessions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-cba4f8bec17b> in <module>
#       5     agent.envs = [env_monitor]
#       6
# ----> 7     sessions = [agent.generate_session(train=False) for _ in range(10)]
#       8     print(sessions)
#
# <ipython-input-12-cba4f8bec17b> in <listcomp>(.0)
#       5     agent.envs = [env_monitor]
#       6
# ----> 7     sessions = [agent.generate_session(train=False) for _ in range(10)]
#       8     print(sessions)
#
# <ipython-input-5-0a9e4a2d95e4> in generate_session(self, t_max, train, batch_size, target_steps)
#     157
#     158             #Only update rewards for those that are running
# --> 159             total_reward[done==False] = total_reward[done==False]+r[done==False]
#     160             s = next_s
#     161             #Set the running environments from the ones that started
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 1

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from IPython.display import HTML

video_names = sorted([s for s in Path('videos').iterdir() if s.suffix == '.mp4'])

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(video_names[-1]))  # You can also try other indices
